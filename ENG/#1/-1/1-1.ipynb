# %% [markdown]
# if) x = 1
#
# <b>x</b> type is <b>int</b>

# %%
x = input('input = ')

print(type(x))
# Out:
# <class 'str'>

# %% [markdown]
# <b><class 'str'></b>
#
# why str?

# %% [markdown]
# if) x = 1
#
# input type is int
# => int(input())

# %%
x = int(input('input = '))

print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# <b><class 'int'></b>
#
# why int?

# %% [markdown]
# if) x = 1
#
# input type is float => float(input())

# %%
x = float(input('input = '))

print(type(x))
print(x)
# Out:
# <class 'float'>
# 1.0

# %%
x = input('input = ')

print(f'x is {x}')
# Out:
# x is 1

# %%
x = input('input = ')
y = 3
# print(f'x is {x}')
# print('x type is',type(x))
print(x + y)
# Out:
# x is 1
# x type is <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       3 print(f'x is {x}')
#       4 print('x type is',type(x))
# ----> 5 print(x + y)
#
# TypeError: can only concatenate str (not "int") to str

# %%
x1 = input('x1 = ')
x2 = int(input('x2 = '))
x3 = float(input('x3 = '))

print(f'x1 is {x1}')
print(f'x2 is {x2}')
print(f'x3 is {x3}')

print('x1 type is',type(x1))
print('x2 type is',type(x2))
print('x3 type is',type(x3))
# Out:
# x1 is 1
# x2 is 1
# x3 is 1.0
# x1 type is <class 'str'>
# x2 type is <class 'int'>
# x3 type is <class 'float'>

# %%
x = float(input('input = '))
y = 3
#print(f'x is {x}')
#print('x type is',type(x))
print(x + y)
# Out:
# 4.0

# %%
x1 = int(input('input = '))
x2 = int(input('input = '))

print(f'x1 is {x1}')
print(f'x2 is {x2}')

print(x1 + x2)
print(x1 - x2)
print(x1 * x2)
print(x1 / x2)
# Out:
# x1 is 10
# x2 is 5
# 15
# 5
# 50
# 2.0

# %%
x1 = float(input('input = '))
x2 = float(input('input = '))

print(f'x1 is {x1}')
print(f'x2 is {x2}')

print(x1 + x2)
print(x1 - x2)
print(x1 * x2)
print(x1 / x2)
# Out:
# x1 is 10.0
# x2 is 5.0
# 15.0
# 5.0
# 50.0
# 2.0
